# %%
import pandas as pd #deal with excel 
import gensim
from gensim import corpora,models

# %%
# Read data
C3 = pd.read_csv('6 Cluster.csv')
C3.shape
# Out:
# (6057, 4)

# %%
C3
# Out:
#       Unnamed: 0  index                                                  0  \
# 0              0  11806  The awarness of individual citizens, administr...
# 1              1  11807  In addition to developing a good understanding...
# 2              2  11808  implement a sensitisation and communication pr...
# 3              3  11809  provide training programs on iss for engineeri...
# 4              4  11810  Define and launch programs of awarness and com...
# 5              5  11811  Define and provide training programs on IT and...
# 6              6  11812  Provide training to introduce to all magistrat...
# 7              7  11813  Boost public confidence in e-commerce by setti...
# 8              8  11814  steering management for tiEN development\t« Ma...
# 9              9  11815  Propose action plan and estimate necessary mea...
# 10            10  11816  Economy\tMake proposals to the government rega...
# ...

# %%
C3_text = C3['0'].tolist()
C3_text
# Out:
# ['The awarness of individual citizens, administrations and enterprises to the challenges of Information Systems Security is of a paramount importance.\r\n',
#  'In addition to developing a good understanding of Information Systems Security, this awarness program should allow individual citizens to be aware of the measures taken to promote digital confidence.\r\n',
#  'implement a sensitisation and communication program about iss\r\n',
#  'provide training programs on iss for engineering students\r\n',
#  'Define and launch programs of awarness and communication on the ISS issues for grand  public, companies and administrations.\r\n',
#  'Define and provide training programs on IT and ISS for engineering students, to help them acquire adequate qualifications according to their area of expertise.\r\n',
#  'Provide training to introduce to all magistrates the basic IT and ISS skills.\r\n',
# ...

# %%
#remove '\r' and punctuations 
import string

NPs_C3 = []
for NP_C3 in C3_text: 
    for ch in NP_C3:
        if ch in string.punctuation:
            NP_C3 = NP_C3.replace(ch,'') #replace punctuation with nothing
        if ch == '\r':
            NP_C3 = NP_C3.replace(ch,' ') #replace \r with space
    NPs_C3.append(NP_C3) 

NPs_C3
# Out:
# ['The awarness of individual citizens administrations and enterprises to the challenges of Information Systems Security is of a paramount importance \n',
#  'In addition to developing a good understanding of Information Systems Security this awarness program should allow individual citizens to be aware of the measures taken to promote digital confidence \n',
#  'implement a sensitisation and communication program about iss \n',
#  'provide training programs on iss for engineering students \n',
#  'Define and launch programs of awarness and communication on the ISS issues for grand  public companies and administrations \n',
#  'Define and provide training programs on IT and ISS for engineering students to help them acquire adequate qualifications according to their area of expertise \n',
#  'Provide training to introduce to all magistrates the basic IT and ISS skills \n',
# ...

# %%
value = [
    ('US', 'United States'),
    ('AF', 'Afghanistan'),
    ('AL', 'Albania'),
    ('DZ', 'Algeria'),
    ('AS', 'American Samoa'),
    ('AD', 'Andorra'),
    ('AO', 'Angola'),
    ('AI', 'Anguilla'),
    ('AQ', 'Antarctica'),
    ('AG', 'Antigua And Barbuda'),
    ('AR', 'Argentina'),
    ('AM', 'Armenia'),
    ('AW', 'Aruba'),
    ('AU', 'Australia'),
    ('AT', 'Austria'),
    ('AZ', 'Azerbaijan'),
    ('BS', 'Bahamas'),
    ('BH', 'Bahrain'),
    ('BD', 'Bangladesh'),
    ('BB', 'Barbados'),
    ('BY', 'Belarus'),
    ('BE', 'Belgium'),
    ('BZ', 'Belize'),
    ('BJ', 'Benin'),
    ('BM', 'Bermuda'),
    ('BT', 'Bhutan'),
    ('BO', 'Bolivia'),
    ('BA', 'Bosnia And Herzegowina'),
    ('BW', 'Botswana'),
    ('BV', 'Bouvet Island'),
    ('BR', 'Brazil'),
    ('BN', 'Brunei Darussalam'),
    ('BG', 'Bulgaria'),
    ('BF', 'Burkina Faso'),
    ('BI', 'Burundi'),
    ('KH', 'Cambodia'),
    ('CM', 'Cameroon'),
    ('CA', 'Canada'),
    ('CV', 'Cape Verde'),
    ('KY', 'Cayman Islands'),
    ('CF', 'Central African Rep'),
    ('TD', 'Chad'),
    ('CL', 'Chile'),
    ('CN', 'China'),
    ('CX', 'Christmas Island'),
    ('CC', 'Cocos Islands'),
    ('CO', 'Colombia'),
    ('KM', 'Comoros'),
    ('CG', 'Congo'),
    ('CK', 'Cook Islands'),
    ('CR', 'Costa Rica'),
    ('CI', 'Cote D`ivoire'),
    ('HR', 'Croatia'),
    ('CU', 'Cuba'),
    ('CY', 'Cyprus'),
    ('CZ', 'Czech Republic'),
    ('DK', 'Denmark'),
    ('DJ', 'Djibouti'),
    ('DM', 'Dominica'),
    ('DO', 'Dominican Republic'),
    ('TP', 'East Timor'),
    ('EC', 'Ecuador'),
    ('EG', 'Egypt'),
    ('SV', 'El Salvador'),
    ('GQ', 'Equatorial Guinea'),
    ('ER', 'Eritrea'),
    ('EE', 'Estonia'),
    ('ET', 'Ethiopia'),
    ('FK', 'Falkland Islands (Malvinas)'),
    ('FO', 'Faroe Islands'),
    ('FJ', 'Fiji'),
    ('FI', 'Finland'),
    ('FR', 'France'),
    ('GF', 'French Guiana'),
    ('PF', 'French Polynesia'),
    ('TF', 'French S. Territories'),
    ('GA', 'Gabon'),
    ('GM', 'Gambia'),
    ('GE', 'Georgia'),
    ('DE', 'Germany'),
    ('GH', 'Ghana'),
    ('GI', 'Gibraltar'),
    ('GR', 'Greece'),
    ('GL', 'Greenland'),
    ('GD', 'Grenada'),
    ('GP', 'Guadeloupe'),
    ('GU', 'Guam'),
    ('GT', 'Guatemala'),
    ('GN', 'Guinea'),
    ('GW', 'Guinea-bissau'),
    ('GY', 'Guyana'),
    ('HT', 'Haiti'),
    ('HN', 'Honduras'),
    ('HK', 'Hong Kong'),
    ('HU', 'Hungary'),
    ('IS', 'Iceland'),
    ('IN', 'India'),
    ('ID', 'Indonesia'),
    ('IR', 'Iran'),
    ('IQ', 'Iraq'),
    ('IE', 'Ireland'),
    ('IL', 'Israel'),
    ('IT', 'Italy'),
    ('JM', 'Jamaica'),
    ('JP', 'Japan'),
    ('JO', 'Jordan'),
    ('KZ', 'Kazakhstan'),
    ('KE', 'Kenya'),
    ('KI', 'Kiribati'),
    ('KP', 'Korea (North)'),
    ('KR', 'Korea (South)'),
    ('KW', 'Kuwait'),
    ('KG', 'Kyrgyzstan'),
    ('LA', 'Laos'),
    ('LV', 'Latvia'),
    ('LB', 'Lebanon'),
    ('LS', 'Lesotho'),
    ('LR', 'Liberia'),
    ('LY', 'Libya'),
    ('LI', 'Liechtenstein'),
    ('LT', 'Lithuania'),
    ('LU', 'Luxembourg'),
    ('MO', 'Macau'),
    ('MK', 'Macedonia'),
    ('MG', 'Madagascar'),
    ('MW', 'Malawi'),
    ('MY', 'Malaysia'),
    ('MV', 'Maldives'),
    ('ML', 'Mali'),
    ('MT', 'Malta'),
    ('MH', 'Marshall Islands'),
    ('MQ', 'Martinique'),
    ('MR', 'Mauritania'),
    ('MU', 'Mauritius'),
    ('YT', 'Mayotte'),
    ('MX', 'Mexico'),
    ('FM', 'Micronesia'),
    ('MD', 'Moldova'),
    ('MC', 'Monaco'),
    ('MN', 'Mongolia'),
    ('MS', 'Montserrat'),
    ('MA', 'Morocco'),
    ('MZ', 'Mozambique'),
    ('MM', 'Myanmar'),
    ('NA', 'Namibia'),
    ('NR', 'Nauru'),
    ('NP', 'Nepal'),
    ('NL', 'Netherlands'),
    ('AN', 'Netherlands Antilles'),
    ('NC', 'New Caledonia'),
    ('NZ', 'New Zealand'),
    ('NI', 'Nicaragua'),
    ('NE', 'Niger'),
    ('NG', 'Nigeria'),
    ('NU', 'Niue'),
    ('NF', 'Norfolk Island'),
    ('MP', 'Northern Mariana Islands'),
    ('NO', 'Norway'),
    ('OM', 'Oman'),
    ('PK', 'Pakistan'),
    ('PW', 'Palau'),
    ('PA', 'Panama'),
    ('PG', 'Papua New Guinea'),
    ('PY', 'Paraguay'),
    ('PE', 'Peru'),
    ('PH', 'Philippines'),
    ('PN', 'Pitcairn'),
    ('PL', 'Poland'),
    ('PT', 'Portugal'),
    ('PR', 'Puerto Rico'),
    ('QA', 'Qatar'),
    ('RE', 'Reunion'),
    ('RO', 'Romania'),
    ('RU', 'Russian Federation'),
    ('RW', 'Rwanda'),
    ('KN', 'Saint Kitts And Nevis'),
    ('LC', 'Saint Lucia'),
    ('VC', 'St Vincent/Grenadines'),
    ('WS', 'Samoa'),
    ('SM', 'San Marino'),
    ('ST', 'Sao Tome'),
    ('SA', 'Saudi Arabia'),
    ('SN', 'Senegal'),
    ('SC', 'Seychelles'),
    ('SL', 'Sierra Leone'),
    ('SG', 'Singapore'),
    ('SK', 'Slovakia'),
    ('SI', 'Slovenia'),
    ('SB', 'Solomon Islands'),
    ('SO', 'Somalia'),
    ('ZA', 'South Africa'),
    ('ES', 'Spain'),
    ('LK', 'Sri Lanka'),
    ('SH', 'St. Helena'),
    ('PM', 'St.Pierre'),
    ('SD', 'Sudan'),
    ('SR', 'Suriname'),
    ('SZ', 'Swaziland'),
    ('SE', 'Sweden'),
    ('CH', 'Switzerland'),
    ('SY', 'Syrian Arab Republic'),
    ('TW', 'Taiwan'),
    ('TJ', 'Tajikistan'),
    ('TZ', 'Tanzania'),
    ('TH', 'Thailand'),
    ('TG', 'Togo'),
    ('TK', 'Tokelau'),
    ('TO', 'Tonga'),
    ('TT', 'Trinidad And Tobago'),
    ('TN', 'Tunisia'),
    ('TR', 'Turkey'),
    ('TM', 'Turkmenistan'),
    ('TV', 'Tuvalu'),
    ('UG', 'Uganda'),
    ('UA', 'Ukraine'),
    ('AE', 'United Arab Emirates'),
    ('UK', 'United Kingdom'),
    ('UY', 'Uruguay'),
    ('UZ', 'Uzbekistan'),
    ('VU', 'Vanuatu'),
    ('VA', 'Vatican City State'),
    ('VE', 'Venezuela'),
    ('VN', 'Viet Nam'),
    ('VG', 'Virgin Islands (British)'),
    ('VI', 'Virgin Islands (U.S.)'),
    ('EH', 'Western Sahara'),
    ('YE', 'Yemen'),
    ('YU', 'Yugoslavia'),
    ('ZR', 'Zaire'),
    ('ZM', 'Zambia'),
    ('ZW', 'Zimbabwe')
]

#remove stop words, to lowercase and tokenize
from nltk.corpus import stopwords
mystopwords = stopwords.words('english')

value = list(pd.DataFrame(value).iloc[:,1])
mystopwords.extend(value)

a = ["cyber","cybersecurity","security","data","cyberspace","also",
    "national","['at","strategy","government","information","government","systems",
     "policy","services","sectors","nici","niss","sector","training","bodies",
    "singapore","rwanda","russian","united","states","must","slovak","areas",
    "areas","federal","online","network","internet","international","australia",
    "technology","australian","within","infrastructure","public","republic",
    "shall","cooperation","digital","development"]
mystopwords.extend(a)

# %%
tokens_list = [[word for word in NP_C3.lower().split(' ') if word not in mystopwords and word.isalpha() and len(word)>3]
         for NP_C3 in NPs_C3]

#remove words that appear only once
from collections import defaultdict
frequency = defaultdict(int)

for tokens in tokens_list:
    for token in tokens:
        frequency[token] += 1
        
tokens_list = [[token for token in tokens if frequency[token]>1]
              for tokens in tokens_list]

print(tokens_list)
# Out:
# [['awarness', 'individual', 'citizens', 'administrations', 'enterprises', 'challenges', 'paramount', 'importance'], ['addition', 'developing', 'good', 'understanding', 'awarness', 'program', 'allow', 'individual', 'citizens', 'aware', 'measures', 'taken', 'promote', 'confidence'], ['implement', 'sensitisation', 'communication', 'program'], ['provide', 'programs', 'engineering', 'students'], ['define', 'launch', 'programs', 'awarness', 'communication', 'issues', 'companies', 'administrations'], ['define', 'provide', 'programs', 'engineering', 'students', 'help', 'acquire', 'adequate', 'qualifications', 'according', 'area', 'expertise'], ['provide', 'introduce', 'basic', 'skills'], ['boost', 'confidence', 'ecommerce', 'setting', 'label', 'retail', 'websites', 'partnership', 'business', 'notably', 'companies'], ['steering', 'management', 'manage', 'overall', 'implementation'], ['propose', 'action', 'plan', 'estimate', 'necessary', 'means'], ['proposals', 'regarding', 'broad', 'orientati
# ...

# %%
# 用文本构建 Gensim 字典
dictionary = corpora.Dictionary(tokens_list)
 
# 去除极端的词（和构建 tf-idf 矩阵时用到 min/max df 参数时很像）
dictionary.filter_extremes(no_below=1, no_above=0.8)
 
# 将字典转化为词典模型（bag of words）作为参考
corpus = [dictionary.doc2bow(tokens) for tokens in tokens_list]

# %%
lda = models.LdaModel(corpus, num_topics=2, 
                            id2word=dictionary, 
                            update_every=5, 
                            chunksize=10000, 
                            passes=20)

# %%
lda.print_topics(2)
# Out:
# [(0,
#   '0.008*"critical" + 0.008*"threats" + 0.006*"ensure" + 0.006*"private" + 0.006*"measures" + 0.005*"capabilities" + 0.005*"defence" + 0.005*"protection" + 0.005*"networks" + 0.005*"response"'),
#  (1,
#   '0.006*"crime" + 0.006*"implementation" + 0.005*"businesses" + 0.005*"risk" + 0.005*"industry" + 0.005*"research" + 0.004*"education" + 0.004*"provide" + 0.004*"attacks" + 0.004*"access"')]

# %%
import nltk
import string

# %%
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# %%
def strip_proppers(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent) if word.islower()]
    return "".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in tokens]).strip()

# %%
type(C3_text)
# Out:
# list

# %%
from gensim import corpora, models, similarities 
import re

#remove proper names
# %time preprocess = [strip_proppers(doc) for doc in C3_text]

#tokenize
# %time tokenized_text = [tokenize_and_stem(text) for text in preprocess]

#remove stop words
# %time texts = [[word for word in text if word not in mystopwords] for text in tokenized_text]
# Out:
# CPU times: user 1.27 s, sys: 14.6 ms, total: 1.29 s
# Wall time: 1.39 s
# CPU times: user 2.54 s, sys: 14.7 ms, total: 2.55 s
# Wall time: 2.56 s
# CPU times: user 389 ms, sys: 2.8 ms, total: 392 ms
# Wall time: 394 ms

# %%
# 用文本构建 Gensim 字典
dictionary = corpora.Dictionary(tokens_list)
 
# 去除极端的词（和构建 tf-idf 矩阵时用到 min/max df 参数时很像）
dictionary.filter_extremes(no_below=5, no_above=0.8)
 
# 将字典转化为词典模型（bag of words）作为参考
corpus = [dictionary.doc2bow(tokens) for tokens in tokens_list]

# %%
lda = models.LdaModel(corpus, id2word=dictionary, 
                      num_topics=4,
                     update_every=5, 
                            chunksize=10000, 
                            passes=30) #fit lda model

lda.print_topics(4)
# Out:
# [(0,
#   '0.019*"research" + 0.018*"development" + 0.016*"innovation" + 0.012*"public" + 0.011*"major" + 0.010*"private" + 0.010*"system" + 0.009*"technology" + 0.008*"scientific" + 0.007*"science"'),
#  (1,
#   '0.024*"australian" + 0.012*"threats" + 0.009*"private" + 0.009*"critical" + 0.008*"infrastructure" + 0.008*"agencies" + 0.008*"ministry" + 0.007*"computer" + 0.007*"cybercrime" + 0.007*"attacks"'),
#  (2,
#   '0.036*"technologies" + 0.018*"technology" + 0.014*"developing" + 0.012*"priorities" + 0.012*"energy" + 0.011*"develop" + 0.010*"critical" + 0.010*"control" + 0.010*"risks" + 0.009*"development"'),
#  (3,
#   '0.011*"australia" + 0.008*"system" + 0.008*"mechanism" + 0.008*"operational" + 0.008*"public" + 0.008*"economic" + 0.008*"range" + 0.007*"digital" + 0.007*"research" + 0.007*"secure"')]
